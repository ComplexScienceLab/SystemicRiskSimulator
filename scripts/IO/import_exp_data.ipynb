# %%
#
# This example writes data to the existing empty dataset created by h5_crtdat.py and then reads it back.
#
import os

import h5py
import numpy as np
import pandas as pd
#
# Open an existing file using default properties.
#

# %%
print("start")
os.chdir("/Users/ethan/LocalFiles/ResearchFile/SystemicRisk")
os.getcwd()
rootPath=os.getcwd()
# Out:
# start
# '/Users/ethan/LocalFiles/ResearchFile/SystemicRisk'

# %%
rootDataPath=os.getcwd()

# %%
# file_BB1jld2 = h5py.File('BB1.jld2','r+')
file_BI1jld2 = h5py.File('BI1.jld2','r+')
# file_BB1h5 = h5py.File('BB1.h5','r+')
# file_BI1h5 = h5py.File('BI1.h5','r+')

#
# Open "dset" dataset under the root group.

# %%
dataset_BI1jld2 = file_BI1jld2["dataBI"]
d1_BI1jld2=dataset_BI1jld2[0]

# %%
v1_d1_BI1jld2=d1_BI1jld2["ilq"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 v1_d1_BI1jld2=d1_BI1jld2["ilq"]
#
# TypeError: 'h5py.h5r.Reference' object is not subscriptable

# %%
dataset_BI1jld2[1]
#
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 dataset_BI1jld2[1]
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/LocalFiles/ResearchFile/SystemicRisk/venv/lib/python3.9/site-packages/h5py/_hl/group.py:307, in Group.__getitem__(self, name)
#     305     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     306 else:
# --> 307     raise TypeError("Accessing a group is done with bytes or str, "
#     308                     " not {}".format(type(name)))
#     310 otype = h5i.get_type(oid)
#     311 if otype == h5i.GROUP:
#
# TypeError: Accessing a group is done with bytes or str,  not <class 'int'>

# %%
# Initialize data object with 0.
#

# %%
data = np.zeros((4,6))
#
# Assign new values
#
for i in range(4):
    for j in range(6):
        data[i][j]= i*6+j+1
#
# Write data
#
print("Writing data...")
dataset[...] = data
#
# Read data back and print it.
#
print("Reading data back...")
data_read = dataset[...]
print("Printing data...")
print(data_read)
#
# Close the file before exiting
#

# %%
file.close()
